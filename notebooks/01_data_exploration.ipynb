# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Loads dataset into a dataframe variable
drug_df = pd.read_csv('../data/raw/Drug_Consumption.csv')
drug_df.head()
# Out:
#    ID    Age Gender                          Education Country Ethnicity  \
# 0   2  25-34      M                   Doctorate degree      UK     White
# 1   3  35-44      M  Professional certificate/ diploma      UK     White
# 2   4  18-24      F                     Masters degree      UK     White
# 3   5  35-44      F                   Doctorate degree      UK     White
# 4   6    65+      F            Left school at 18 years  Canada     White
#
#     Nscore   Escore   Oscore   AScore  ...  Ecstasy  Heroin  Ketamine Legalh  \
# 0 -0.67825  1.93886  1.43533  0.76096  ...      CL4     CL0       CL2    CL0
# 1 -0.46725  0.80523 -0.84732 -1.62090  ...      CL0     CL0       CL0    CL0
# 2 -0.14882 -0.80615 -0.01928  0.59042  ...      CL0     CL0       CL2    CL0
# 3  0.73545 -1.63340 -0.45174 -0.30172  ...      CL1     CL0       CL0    CL1
# 4 -0.67825 -0.30033 -1.55521  2.03972  ...      CL0     CL0       CL0    CL0
#
#    LSD Meth Mushrooms Nicotine Semer  VSA
# 0  CL2  CL3       CL0      CL4   CL0  CL0
# 1  CL0  CL0       CL1      CL0   CL0  CL0
# 2  CL0  CL0       CL0      CL2   CL0  CL0
# 3  CL0  CL0       CL2      CL2   CL0  CL0
# 4  CL0  CL0       CL0      CL6   CL0  CL0
#
# [5 rows x 32 columns]

# %%
# Views random sample of 20 rows
drug_df.sample(20)
# Out:
#         ID    Age Gender                                          Education  \
# 1295  1300  25-34      M  Some college or university, no certificate or ...
# 1035  1040  18-24      F  Some college or university, no certificate or ...
# 88      90  35-44      F                                     Masters degree
# 860    865  18-24      M  Some college or university, no certificate or ...
# 420    424  35-44      M                  Professional certificate/ diploma
# 986    991  18-24      M  Some college or university, no certificate or ...
# 1845  1850  45-54      M                  Professional certificate/ diploma
# 1202  1207  18-24      F                            Left school at 18 years
# 1866  1871  18-24      F  Some college or university, no certificate or ...
# 654    658  45-54      M                  Professional certificate/ diploma
# 71      73  45-54      M                            Left school at 18 years
# 374    378  45-54      F                                     Masters degree
# 869    874  25-34      F                                     Masters degree
# 1332  1337  18-24      F                                  University degree
# 1552  1557  18-24      F                                     Masters degree
# 643    647  18-24      F                                  University degree
# 887    892  18-24      M  Some college or university, no certificate or ...
# 1315  1320  35-44      M                                  University degree
# 119    121  25-34      F                                     Masters degree
# 1049  1054  18-24      M                            Left school at 18 years
#
#      Country Ethnicity   Nscore   Escore   Oscore   AScore  ...  Ecstasy  \
# 1295     USA     White  0.91093 -0.15487  1.65653  0.13136  ...      CL2
# 1035     USA     White  0.22393 -0.80615  0.72330  2.23427  ...      CL0
# 88        UK     White  0.91093 -0.57545  0.29338 -0.60633  ...      CL0
# 860   Canada     White -1.86962  1.28610  2.15324  0.76096  ...      CL0
# 420       UK     White -0.79151 -0.15487 -0.01928  1.81866  ...      CL1
# 986      USA     White  1.72012 -0.57545  1.65653  0.13136  ...      CL2
# 1845     USA     Black -1.05308 -0.94779 -0.97631 -0.76096  ...      CL0
# 1202      UK     White -1.05308 -0.57545 -0.01928 -2.07848  ...      CL0
# 1866     USA     White  1.13281 -0.43999  0.29338 -0.76096  ...      CL2
# 654       UK     White  1.13281 -1.37639  1.43533 -0.45321  ...      CL2
# 71        UK     White -1.55078  0.96248 -0.01928  0.43852  ...      CL0
# 374       UK     White -0.92104  0.00332 -0.71727  0.13136  ...      CL0
# 869      USA     White -0.67825 -0.43999 -0.01928  0.59042  ...      CL0
# 1332      UK     White  0.04257  1.58487 -0.71727  0.76096  ...      CL0
# 1552      UK     White  0.31287  0.80523 -0.97631  0.28783  ...      CL0
# 643       UK     White -0.46725 -0.15487 -0.31776 -0.15487  ...      CL0
# 887      USA     Other  0.13606  0.96248  1.06238  0.59042  ...      CL4
# 1315     USA     White -0.67825 -0.30033 -0.31776 -0.15487  ...      CL2
# 119       UK     White -1.05308  0.63779 -0.97631 -1.07533  ...      CL0
# 1049  Canada     White  1.23461 -0.57545 -1.55521 -1.92595  ...      CL4
#
#       Heroin  Ketamine Legalh  LSD Meth Mushrooms Nicotine Semer  VSA
# 1295     CL0       CL0    CL3  CL2  CL2       CL2      CL3   CL0  CL2
# 1035     CL0       CL0    CL3  CL0  CL0       CL0      CL3   CL0  CL3
# 88       CL0       CL0    CL0  CL1  CL0       CL1      CL0   CL0  CL1
# 860      CL0       CL0    CL3  CL5  CL2       CL3      CL5   CL0  CL0
# 420      CL0       CL0    CL2  CL1  CL1       CL1      CL6   CL0  CL1
# 986      CL6       CL0    CL3  CL0  CL4       CL2      CL6   CL0  CL2
# 1845     CL0       CL0    CL2  CL1  CL0       CL0      CL6   CL0  CL0
# 1202     CL0       CL0    CL2  CL0  CL0       CL0      CL6   CL0  CL2
# 1866     CL2       CL0    CL3  CL2  CL0       CL2      CL6   CL0  CL0
# 654      CL1       CL1    CL1  CL1  CL1       CL1      CL6   CL0  CL0
# 71       CL0       CL0    CL0  CL0  CL0       CL0      CL2   CL0  CL0
# 374      CL0       CL0    CL0  CL0  CL0       CL0      CL2   CL0  CL0
# 869      CL0       CL0    CL0  CL1  CL0       CL2      CL2   CL0  CL0
# 1332     CL0       CL0    CL0  CL0  CL0       CL0      CL2   CL0  CL0
# 1552     CL0       CL0    CL0  CL0  CL0       CL0      CL6   CL0  CL0
# 643      CL0       CL0    CL0  CL0  CL0       CL0      CL2   CL0  CL0
# 887      CL0       CL0    CL3  CL4  CL0       CL3      CL4   CL0  CL3
# 1315     CL0       CL0    CL3  CL1  CL1       CL6      CL6   CL0  CL1
# 119      CL0       CL0    CL0  CL1  CL0       CL1      CL2   CL0  CL0
# 1049     CL5       CL0    CL4  CL3  CL5       CL3      CL6   CL0  CL0
#
# [20 rows x 32 columns]

# %%
# Displays the numerical summary statistics of the dataframe
drug_df.describe()
# Out:
#                 ID       Nscore       Escore       Oscore       AScore  \
# count  1884.000000  1884.000000  1884.000000  1884.000000  1884.000000
# mean    945.796178    -0.000119     0.000143    -0.000225     0.000242
# std     544.877779     0.998345     0.997625     0.996402     0.997481
# min       2.000000    -3.464360    -3.273930    -3.273930    -3.464360
# 25%     474.750000    -0.678250    -0.695090    -0.717270    -0.606330
# 50%     946.500000     0.042570     0.003320    -0.019280    -0.017290
# 75%    1417.250000     0.629670     0.637790     0.723300     0.760960
# max    1888.000000     3.273930     3.273930     2.901610     3.464360
#
#             Cscore    Impulsive           SS
# count  1884.000000  1884.000000  1884.000000
# mean     -0.000383     0.007335    -0.002667
# std       0.997787     0.954674     0.963575
# min      -3.464360    -2.555240    -2.078480
# 25%      -0.652530    -0.711260    -0.525930
# 50%      -0.006650    -0.217120     0.079870
# 75%       0.584890     0.529750     0.765400
# max       3.464360     2.901610     1.921730

# %%
# Displays the shape of the dataframe
print(f"Shape: {drug_df.shape}")
# Out:
# Shape: (1884, 32)

# %%
# Displays information about the dataframe i.e. data types, non-null counts, memory usage, row entries
drug_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1884 entries, 0 to 1883
# Data columns (total 32 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1884 non-null   int64
#  1   Age        1884 non-null   object
#  2   Gender     1884 non-null   object
#  3   Education  1884 non-null   object
#  4   Country    1884 non-null   object
#  5   Ethnicity  1884 non-null   object
#  6   Nscore     1884 non-null   float64
#  7   Escore     1884 non-null   float64
#  8   Oscore     1884 non-null   float64
#  9   AScore     1884 non-null   float64
#  10  Cscore     1884 non-null   float64
#  11  Impulsive  1884 non-null   float64
#  12  SS         1884 non-null   float64
#  13  Alcohol    1884 non-null   object
#  14  Amphet     1884 non-null   object
#  15  Amyl       1884 non-null   object
#  16  Benzos     1884 non-null   object
#  17  Caff       1884 non-null   object
#  18  Cannabis   1884 non-null   object
#  19  Choc       1884 non-null   object
#  20  Coke       1884 non-null   object
#  21  Crack      1884 non-null   object
#  22  Ecstasy    1884 non-null   object
#  23  Heroin     1884 non-null   object
#  24  Ketamine   1884 non-null   object
#  25  Legalh     1884 non-null   object
#  26  LSD        1884 non-null   object
#  27  Meth       1884 non-null   object
#  28  Mushrooms  1884 non-null   object
#  29  Nicotine   1884 non-null   object
#  30  Semer      1884 non-null   object
#  31  VSA        1884 non-null   object
# dtypes: float64(7), int64(1), object(24)
# memory usage: 471.1+ KB

# %%
# Displays the number of missing values in each column
drug_df.isnull().sum()
# Out:
# ID           0
# Age          0
# Gender       0
# Education    0
# Country      0
# Ethnicity    0
# Nscore       0
# Escore       0
# Oscore       0
# AScore       0
# Cscore       0
# Impulsive    0
# SS           0
# Alcohol      0
# Amphet       0
# Amyl         0
# Benzos       0
# Caff         0
# Cannabis     0
# Choc         0
# Coke         0
# Crack        0
# Ecstasy      0
# Heroin       0
# Ketamine     0
# Legalh       0
# LSD          0
# Meth         0
# Mushrooms    0
# Nicotine     0
# Semer        0
# VSA          0
# dtype: int64

# %%
# Checks for duplicate rows in the dataframe
drug_df.duplicated().sum()
drug_df.columns
# Out:
# np.int64(0)

# %%
# Removes leading/trailing whitespace from column names
drug_df.rename(columns=lambda x: x.strip(), inplace=True)

# Displays the column names of the dataframe
drug_df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Education', 'Country', 'Ethnicity', 'Nscore',
#        'Escore', 'Oscore', 'AScore', 'Cscore', 'Impulsive', 'SS', 'Alcohol',
#        'Amphet', 'Amyl', 'Benzos', 'Caff', 'Cannabis', 'Choc', 'Coke', 'Crack',
#        'Ecstasy', 'Heroin', 'Ketamine', 'Legalh', 'LSD', 'Meth', 'Mushrooms',
#        'Nicotine', 'Semer', 'VSA'],
#       dtype='object')
