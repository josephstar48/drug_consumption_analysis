# %%
import sys
sys.path.append('..')
from src.visualization import * 
from src.data_cleaning import *

# %%
# Loads cleaned dataset into a dataframe variable

cleaned_drug_df = load_dataset(FILEPATH_CLEANED)

# %%
cleaned_drug_df.head()
# Out:
#    id   age gender                          education country ethnicity  \
# 0   2  29.5      M                   Doctorate degree      UK     White
# 1   3  39.5      M  Professional certificate/ diploma      UK     White
# 2   4  21.0      F                     Masters degree      UK     White
# 3   5  39.5      F                   Doctorate degree      UK     White
# 4   6  70.0      F            Left school at 18 years  Canada     White
#
#    neuroticism_nscore  extraversion_escore  openness_oscore  \
# 0                0.41                 0.80             0.76
# 1                0.44                 0.62             0.39
# 2                0.49                 0.38             0.53
# 3                0.62                 0.25             0.46
# 4                0.41                 0.45             0.28
#
#    agreeableness_ascore  ...  lsd  methamphetamine  magic_mushrooms  nicotine  \
# 0                  0.61  ...    2                3                0         4
# ...

# %%
cleaned_drug_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1884 entries, 0 to 1883
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1884 non-null   int64
#  1   age                       1884 non-null   float64
#  2   gender                    1884 non-null   object
#  3   education                 1884 non-null   object
#  4   country                   1884 non-null   object
#  5   ethnicity                 1884 non-null   object
#  6   neuroticism_nscore        1884 non-null   float64
#  7   extraversion_escore       1884 non-null   float64
#  8   openness_oscore           1884 non-null   float64
#  9   agreeableness_ascore      1884 non-null   float64
#  10  conscientiousness_cscore  1884 non-null   float64
#  11  impulsivity_impulsive     1884 non-null   float64
#  12  sensation_seeking_ss      1884 non-null   float64
# ...

# %%
# Creates Counterplot graph for demographics of age distribution

plot_age_distribution(cleaned_drug_df, 'age')

# %%
# Creates Counteplot Graph for gender distribution

plot_gender_distribution(cleaned_drug_df, 'gender')

# %%
# Creates Stack bar for Most Frequently Used Drugs by Drug Types

drug_columns_lst = ['alcohol', 'amphetamine', 'amyl_nitrate', 'benzodiazepines', 'caffeine', 'cannabis', 'chocolate', 'cocaine', 'crack_cocaine', 'ecstasy', 'heroin', 'ketamine', 'legal_highs', 'lsd', 'methamphetamine', 'magic_mushrooms', 'nicotine', 'semer', 'volatile_solvent_abuse']

plot_drug_usage_frequency(cleaned_drug_df, drug_columns_lst)

# %%
# Creates correlation heatmap for personality traits  
plot_personality_trait_correlation(cleaned_drug_df)

# %%
# Creates correlation heatmap for personality traits and drug use

drug_columns_lst = ['alcohol', 'amphetamine', 'amyl_nitrate', 'benzodiazepines', 'caffeine', 'cannabis', 'chocolate', 'cocaine', 'crack_cocaine', 'ecstasy', 'heroin', 'ketamine', 'legal_highs', 'lsd', 'methamphetamine', 'magic_mushrooms', 'nicotine', 'semer', 'volatile_solvent_abuse']

plot_personality_drug_correlation_heatmap(cleaned_drug_df, drug_columns_lst)

# %%
# Stacked Bar for personality traits and drug intensity use

plot_personality_drug_intensity_stacked(cleaned_drug_df)

# %%
# Creates a bar chart of the top 5 most commonly used substances for quick insight.

drug_columns_lst = ['alcohol', 'amphetamine', 'amyl_nitrate', 'benzodiazepines', 'caffeine', 'cannabis', 'chocolate', 'cocaine', 'crack_cocaine', 'ecstasy', 'heroin', 'ketamine', 'legal_highs', 'lsd', 'methamphetamine', 'magic_mushrooms', 'nicotine', 'semer', 'volatile_solvent_abuse']

plot_top_five_drugs(cleaned_drug_df, drug_columns_lst)

# %%
# Creates a pairplot to find patterns between different drug types and user groups.

plot_drug_intensity_by_demographics(cleaned_drug_df)

# %%
# Creates barplot to explore how impulsivity affects use of drugs like cannabis, cocaine, and LSD.

pers_traits_col =  [
        'neuroticism_nscore', 'extraversion_escore', 'openness_oscore',
        'agreeableness_ascore', 'conscientiousness_cscore',
        'impulsivity_impulsive', 'sensation_seeking_ss'
    ]


drug_columns_lst = ['alcohol', 'amphetamine', 'amyl_nitrate', 'benzodiazepines', 'caffeine', 'cannabis', 'chocolate', 'cocaine', 'crack_cocaine', 'ecstasy', 'heroin', 'ketamine', 'legal_highs', 'lsd', 'methamphetamine', 'magic_mushrooms', 'nicotine', 'semer', 'volatile_solvent_abuse']

plot_trait_drug_barplots(cleaned_drug_df, pers_traits_col, drug_columns_lst)
