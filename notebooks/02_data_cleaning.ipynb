# %%
import sys
sys.path.append('..')
from src.data_cleaning import *
from src.visualization import *

# %%
# Loads raw dataset into a dataframe variable
cleaning_drug_df = load_dataset(FILEPATH_RAW)

# %%
cleaning_drug_df.head()
# Out:
#    ID    Age Gender                          Education Country Ethnicity  \
# 0   2  25-34      M                   Doctorate degree      UK     White
# 1   3  35-44      M  Professional certificate/ diploma      UK     White
# 2   4  18-24      F                     Masters degree      UK     White
# 3   5  35-44      F                   Doctorate degree      UK     White
# 4   6    65+      F            Left school at 18 years  Canada     White
#
#     Nscore   Escore   Oscore   AScore  ...  Ecstasy  Heroin  Ketamine Legalh  \
# 0 -0.67825  1.93886  1.43533  0.76096  ...      CL4     CL0       CL2    CL0
# 1 -0.46725  0.80523 -0.84732 -1.62090  ...      CL0     CL0       CL0    CL0
# 2 -0.14882 -0.80615 -0.01928  0.59042  ...      CL0     CL0       CL2    CL0
# 3  0.73545 -1.63340 -0.45174 -0.30172  ...      CL1     CL0       CL0    CL1
# 4 -0.67825 -0.30033 -1.55521  2.03972  ...      CL0     CL0       CL0    CL0
#
#    LSD Meth Mushrooms Nicotine Semer  VSA
# ...

# %%
cleaning_drug_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1884 entries, 0 to 1883
# Data columns (total 32 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1884 non-null   int64
#  1   Age        1884 non-null   object
#  2   Gender     1884 non-null   object
#  3   Education  1884 non-null   object
#  4   Country    1884 non-null   object
#  5   Ethnicity  1884 non-null   object
#  6   Nscore     1884 non-null   float64
#  7   Escore     1884 non-null   float64
#  8   Oscore     1884 non-null   float64
#  9   AScore     1884 non-null   float64
#  10  Cscore     1884 non-null   float64
#  11  Impulsive  1884 non-null   float64
#  12  SS         1884 non-null   float64
#  13  Alcohol    1884 non-null   object
#  14  Amphet     1884 non-null   object
#  15  Amyl       1884 non-null   object
#  16  Benzos     1884 non-null   object
#  17  Caff       1884 non-null   object
#  18  Cannabis   1884 non-null   object
# ...

# %%
"""Converts drug use ratings in specified columns to numerical values."""

ratings_lst = cleaning_drug_df[['Alcohol', 'Amphet', 'Amyl', 'Benzos', 'Caff', 'Cannabis', 'Choc', 'Coke', 'Crack', 'Ecstasy', 'Heroin', 'Ketamine', 'Legalh', 'LSD', 'Meth', 'Mushrooms', 'Nicotine', 'Semer', 'VSA']].columns.tolist()

cleaning_drug_df_copy = cleaning_drug_df.copy()

cleaning_drug_df_v2 = convert_drug_use_ratings(cleaning_drug_df_copy, ratings_lst)
# Out:
# c:\Users\Owner\Desktop\Data Science Bootcamp\Midterm_Project\drug_consumption_analysis\notebooks\..\src\data_cleaning.py:38: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[drug_cols] = df[drug_cols].replace(category_dict)

# %%
cleaning_drug_df_v2.head()
# Out:
#    ID    Age Gender                          Education Country Ethnicity  \
# 0   2  25-34      M                   Doctorate degree      UK     White
# 1   3  35-44      M  Professional certificate/ diploma      UK     White
# 2   4  18-24      F                     Masters degree      UK     White
# 3   5  35-44      F                   Doctorate degree      UK     White
# 4   6    65+      F            Left school at 18 years  Canada     White
#
#     Nscore   Escore   Oscore   AScore  ...  Ecstasy  Heroin  Ketamine  Legalh  \
# 0 -0.67825  1.93886  1.43533  0.76096  ...        4       0         2       0
# 1 -0.46725  0.80523 -0.84732 -1.62090  ...        0       0         0       0
# 2 -0.14882 -0.80615 -0.01928  0.59042  ...        0       0         2       0
# 3  0.73545 -1.63340 -0.45174 -0.30172  ...        1       0         0       1
# 4 -0.67825 -0.30033 -1.55521  2.03972  ...        0       0         0       0
#
#    LSD  Meth  Mushrooms  Nicotine  Semer  VSA
# ...

# %%
cleaning_drug_df_v2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1884 entries, 0 to 1883
# Data columns (total 32 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1884 non-null   int64
#  1   Age        1884 non-null   object
#  2   Gender     1884 non-null   object
#  3   Education  1884 non-null   object
#  4   Country    1884 non-null   object
#  5   Ethnicity  1884 non-null   object
#  6   Nscore     1884 non-null   float64
#  7   Escore     1884 non-null   float64
#  8   Oscore     1884 non-null   float64
#  9   AScore     1884 non-null   float64
#  10  Cscore     1884 non-null   float64
#  11  Impulsive  1884 non-null   float64
#  12  SS         1884 non-null   float64
#  13  Alcohol    1884 non-null   int64
#  14  Amphet     1884 non-null   int64
#  15  Amyl       1884 non-null   int64
#  16  Benzos     1884 non-null   int64
#  17  Caff       1884 non-null   int64
#  18  Cannabis   1884 non-null   int64
# ...

# %%
"""Converts age ranges in Age column to their midpoint numerical values."""

age_range_lst = cleaning_drug_df_v2[['Age']].columns.tolist()

cleaning_drug_df_v2_copy = cleaning_drug_df_v2.copy()

cleaning_drug_df_v3 = convert_to_midpoint(cleaning_drug_df_v2_copy, age_range_lst)
# Out:
# c:\Users\Owner\Desktop\Data Science Bootcamp\Midterm_Project\drug_consumption_analysis\notebooks\..\src\data_cleaning.py:53: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[age_col] = df[age_col].replace(midpoint_dict)

# %%
cleaning_drug_df_v3.head()
# Out:
#    ID   Age Gender                          Education Country Ethnicity  \
# 0   2  29.5      M                   Doctorate degree      UK     White
# 1   3  39.5      M  Professional certificate/ diploma      UK     White
# 2   4  21.0      F                     Masters degree      UK     White
# 3   5  39.5      F                   Doctorate degree      UK     White
# 4   6  70.0      F            Left school at 18 years  Canada     White
#
#     Nscore   Escore   Oscore   AScore  ...  Ecstasy  Heroin  Ketamine  Legalh  \
# 0 -0.67825  1.93886  1.43533  0.76096  ...        4       0         2       0
# 1 -0.46725  0.80523 -0.84732 -1.62090  ...        0       0         0       0
# 2 -0.14882 -0.80615 -0.01928  0.59042  ...        0       0         2       0
# 3  0.73545 -1.63340 -0.45174 -0.30172  ...        1       0         0       1
# 4 -0.67825 -0.30033 -1.55521  2.03972  ...        0       0         0       0
#
#    LSD  Meth  Mushrooms  Nicotine  Semer  VSA
# ...

# %%
cleaning_drug_df_v3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1884 entries, 0 to 1883
# Data columns (total 32 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1884 non-null   int64
#  1   Age        1884 non-null   float64
#  2   Gender     1884 non-null   object
#  3   Education  1884 non-null   object
#  4   Country    1884 non-null   object
#  5   Ethnicity  1884 non-null   object
#  6   Nscore     1884 non-null   float64
#  7   Escore     1884 non-null   float64
#  8   Oscore     1884 non-null   float64
#  9   AScore     1884 non-null   float64
#  10  Cscore     1884 non-null   float64
#  11  Impulsive  1884 non-null   float64
#  12  SS         1884 non-null   float64
#  13  Alcohol    1884 non-null   int64
#  14  Amphet     1884 non-null   int64
#  15  Amyl       1884 non-null   int64
#  16  Benzos     1884 non-null   int64
#  17  Caff       1884 non-null   int64
#  18  Cannabis   1884 non-null   int64
# ...

# %%
"""Changes column headers for personality traits to more descriptive names."""

column_rename_df_copy = cleaning_drug_df_v3.copy()
renamed_columns_df = rename_personality_traits(column_rename_df_copy)

# %%
renamed_columns_df.head()
# Out:
#    ID   Age Gender                          Education Country Ethnicity  \
# 0   2  29.5      M                   Doctorate degree      UK     White
# 1   3  39.5      M  Professional certificate/ diploma      UK     White
# 2   4  21.0      F                     Masters degree      UK     White
# 3   5  39.5      F                   Doctorate degree      UK     White
# 4   6  70.0      F            Left school at 18 years  Canada     White
#
#    neuroticism_nscore  extraversion_escore  openness_oscore  \
# 0            -0.67825              1.93886          1.43533
# 1            -0.46725              0.80523         -0.84732
# 2            -0.14882             -0.80615         -0.01928
# 3             0.73545             -1.63340         -0.45174
# 4            -0.67825             -0.30033         -1.55521
#
#    agreeableness_ascore  ...  Ecstasy  Heroin  Ketamine  Legalh  LSD  Meth  \
# 0               0.76096  ...        4       0         2       0    2     3
# ...

# %%
renamed_columns_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1884 entries, 0 to 1883
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        1884 non-null   int64
#  1   Age                       1884 non-null   float64
#  2   Gender                    1884 non-null   object
#  3   Education                 1884 non-null   object
#  4   Country                   1884 non-null   object
#  5   Ethnicity                 1884 non-null   object
#  6   neuroticism_nscore        1884 non-null   float64
#  7   extraversion_escore       1884 non-null   float64
#  8   openness_oscore           1884 non-null   float64
#  9   agreeableness_ascore      1884 non-null   float64
#  10  conscientiousness_cscore  1884 non-null   float64
#  11  impulsivity_impulsive     1884 non-null   float64
#  12  sensation_seeking_ss      1884 non-null   float64
# ...

# %%
"""
Creates a drug_intensity_position column representing total consumption across substances.
"""
drug_cols = ['Alcohol', 'Amphet', 'Amyl', 'Benzos', 'Caff', 'Cannabis', 'Choc', 'Coke', 'Crack', 'Ecstasy', 'Heroin', 'Ketamine', 'Legalh', 'LSD', 'Meth', 'Mushrooms', 'Nicotine', 'Semer', 'VSA']

renamed_columns_df_copy = renamed_columns_df.copy()

added_column_df = add_drug_intensity_position(renamed_columns_df_copy, drug_cols)

# %%
added_column_df.head()
# Out:
#    ID   Age Gender                          Education Country Ethnicity  \
# 0   2  29.5      M                   Doctorate degree      UK     White
# 1   3  39.5      M  Professional certificate/ diploma      UK     White
# 2   4  21.0      F                     Masters degree      UK     White
# 3   5  39.5      F                   Doctorate degree      UK     White
# 4   6  70.0      F            Left school at 18 years  Canada     White
#
#    neuroticism_nscore  extraversion_escore  openness_oscore  \
# 0            -0.67825              1.93886          1.43533
# 1            -0.46725              0.80523         -0.84732
# 2            -0.14882             -0.80615         -0.01928
# 3             0.73545             -1.63340         -0.45174
# 4            -0.67825             -0.30033         -1.55521
#
#    agreeableness_ascore  ...  Heroin  Ketamine  Legalh  LSD  Meth  Mushrooms  \
# 0               0.76096  ...       0         2       0    2     3          0
# ...

# %%
""" Changes column names for some of the drug column names to be more descriptive. """

added_column_df_copy = added_column_df.copy()
renamed_drug_headers_df = rename_drug_columns(added_column_df_copy)

# %%
renamed_drug_headers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1884 entries, 0 to 1883
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        1884 non-null   int64
#  1   Age                       1884 non-null   float64
#  2   Gender                    1884 non-null   object
#  3   Education                 1884 non-null   object
#  4   Country                   1884 non-null   object
#  5   Ethnicity                 1884 non-null   object
#  6   neuroticism_nscore        1884 non-null   float64
#  7   extraversion_escore       1884 non-null   float64
#  8   openness_oscore           1884 non-null   float64
#  9   agreeableness_ascore      1884 non-null   float64
#  10  conscientiousness_cscore  1884 non-null   float64
#  11  impulsivity_impulsive     1884 non-null   float64
#  12  sensation_seeking_ss      1884 non-null   float64
# ...

# %%
"""
Transforms personality traits scores to numeric values between 0 and 1. This makes comparisons cleaner and more intuitive when plotting graphs
"""

personality_trait_lst = renamed_drug_headers_df[['neuroticism_nscore','extraversion_escore','openness_oscore', 'agreeableness_ascore', 'conscientiousness_cscore', 'impulsivity_impulsive', 'sensation_seeking_ss']].columns.tolist()

renamed_drug_headers_df_copy = renamed_drug_headers_df.copy()

added_min_max_personality_df = apply_min_max_scaling(renamed_drug_headers_df_copy, personality_trait_lst)

# %%
added_min_max_personality_df.head()
# Out:
#    ID   Age Gender                          Education Country Ethnicity  \
# 0   2  29.5      M                   Doctorate degree      UK     White
# 1   3  39.5      M  Professional certificate/ diploma      UK     White
# 2   4  21.0      F                     Masters degree      UK     White
# 3   5  39.5      F                   Doctorate degree      UK     White
# 4   6  70.0      F            Left school at 18 years  Canada     White
#
#    neuroticism_nscore  extraversion_escore  openness_oscore  \
# 0            0.413474             0.796106         0.762567
# 1            0.444788             0.622976         0.392939
# 2            0.492045             0.376883         0.527023
# 3            0.623275             0.250544         0.456995
# 4            0.413474             0.454133         0.278311
#
#    agreeableness_ascore  ...  Heroin  Ketamine  legal_highs  LSD  \
# 0              0.609827  ...       0         2            0    2
# ...

# %%
added_min_max_personality_df[['neuroticism_nscore','extraversion_escore','openness_oscore', 'agreeableness_ascore', 'conscientiousness_cscore', 'impulsivity_impulsive', 'sensation_seeking_ss']] = added_min_max_personality_df[['neuroticism_nscore','extraversion_escore','openness_oscore', 'agreeableness_ascore', 'conscientiousness_cscore', 'impulsivity_impulsive', 'sensation_seeking_ss']].round(2)

added_min_max_personality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1884 entries, 0 to 1883
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        1884 non-null   int64
#  1   Age                       1884 non-null   float64
#  2   Gender                    1884 non-null   object
#  3   Education                 1884 non-null   object
#  4   Country                   1884 non-null   object
#  5   Ethnicity                 1884 non-null   object
#  6   neuroticism_nscore        1884 non-null   float64
#  7   extraversion_escore       1884 non-null   float64
#  8   openness_oscore           1884 non-null   float64
#  9   agreeableness_ascore      1884 non-null   float64
#  10  conscientiousness_cscore  1884 non-null   float64
#  11  impulsivity_impulsive     1884 non-null   float64
#  12  sensation_seeking_ss      1884 non-null   float64
# ...

# %%
""" Creates function to visualize and verify data balance across demographics, gender, and personality traits. """

demographic_cols_lst = added_min_max_personality_df[['neuroticism_nscore','extraversion_escore','openness_oscore', 'agreeableness_ascore', 'conscientiousness_cscore', 'impulsivity_impulsive', 'sensation_seeking_ss']].columns.tolist()

personality_traits_lst = added_min_max_personality_df[['Age', 'Gender', 'Education', 'Country', 'Ethnicity']].columns.tolist()

visualize_data_balance(added_min_max_personality_df, demographic_cols_lst, personality_traits_lst)

# %%
added_min_max_personality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1884 entries, 0 to 1883
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        1884 non-null   int64
#  1   Age                       1884 non-null   float64
#  2   Gender                    1884 non-null   object
#  3   Education                 1884 non-null   object
#  4   Country                   1884 non-null   object
#  5   Ethnicity                 1884 non-null   object
#  6   neuroticism_nscore        1884 non-null   float64
#  7   extraversion_escore       1884 non-null   float64
#  8   openness_oscore           1884 non-null   float64
#  9   agreeableness_ascore      1884 non-null   float64
#  10  conscientiousness_cscore  1884 non-null   float64
#  11  impulsivity_impulsive     1884 non-null   float64
#  12  sensation_seeking_ss      1884 non-null   float64
# ...

# %%
"""Creates usage_frequency and heavy_user columns to flag frequent daily and weekly drug users."""

drug_columns_lst = added_min_max_personality_df[['Alcohol', 'amphetamine', 'amyl_nitrate', 'benzodiazepines', 'caffeine', 'Cannabis', 'chocolate', 'cocaine', 'crack_cocaine', 'Ecstasy', 'Heroin', 'Ketamine', 'legal_highs', 'LSD', 'methamphetamine', 'magic_mushrooms', 'Nicotine', 'Semer', 'volatile_solvent_abuse']].columns.tolist()

added_usage_heavy_user_df_copy = added_min_max_personality_df.copy()

drug_usage_cols = flag_heavy_users(added_usage_heavy_user_df_copy, drug_columns_lst)
# Out:
#        Usage Frequency  heavy_user
#             Never Used       18889
# Used Over a Decade Ago        2194
#    Used in Last Decade        3005
#      Used in Last Year        3046
#           Monthly User        1872
#            Weekly User        2598
#             Daily User        4192

# %%
added_usage_heavy_user_df_copy = replace_outliers_with_mean(added_usage_heavy_user_df_copy, 'usage_frequency').round(2)

# %%
added_usage_heavy_user_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1884 entries, 0 to 1883
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        1884 non-null   int64
#  1   Age                       1884 non-null   float64
#  2   Gender                    1884 non-null   object
#  3   Education                 1884 non-null   object
#  4   Country                   1884 non-null   object
#  5   Ethnicity                 1884 non-null   object
#  6   neuroticism_nscore        1884 non-null   float64
#  7   extraversion_escore       1884 non-null   float64
#  8   openness_oscore           1884 non-null   float64
#  9   agreeableness_ascore      1884 non-null   float64
#  10  conscientiousness_cscore  1884 non-null   float64
#  11  impulsivity_impulsive     1884 non-null   float64
#  12  sensation_seeking_ss      1884 non-null   float64
# ...

# %%
added_usage_heavy_user_df_copy.head()
# Out:
#    ID   Age Gender                          Education Country Ethnicity  \
# 0   2  29.5      M                   Doctorate degree      UK     White
# 1   3  39.5      M  Professional certificate/ diploma      UK     White
# 2   4  21.0      F                     Masters degree      UK     White
# 3   5  39.5      F                   Doctorate degree      UK     White
# 4   6  70.0      F            Left school at 18 years  Canada     White
#
#    neuroticism_nscore  extraversion_escore  openness_oscore  \
# 0                0.41                 0.80             0.76
# 1                0.44                 0.62             0.39
# 2                0.49                 0.38             0.53
# 3                0.62                 0.25             0.46
# 4                0.41                 0.45             0.28
#
#    agreeableness_ascore  ...  legal_highs  LSD  methamphetamine  \
# 0                  0.61  ...            0    2                3
# ...

# %%
""" Converts tuple to Series"""

drug_usage_cols_series = pd.DataFrame({
    'Usage Frequency': [
        'Never Used', 
        'Used Over a Decade Ago', 
        'Used in Last Decade', 
        'Used in Last Year', 
        'Monthly User', 
        'Weekly User', 
        'Daily User'
    ],
    'heavy_user': [18889, 2194, 3005, 3046, 1872, 2598, 4192]
})

# %%
drug_usage_cols_series.head(6)
# Out:
#           Usage Frequency  heavy_user
# 0              Never Used       18889
# 1  Used Over a Decade Ago        2194
# 2     Used in Last Decade        3005
# 3       Used in Last Year        3046
# 4            Monthly User        1872
# 5             Weekly User        2598

# %%
""" Sorts the drug usage frequency data in descending order based on heavy users."""

drug_usage_cols_series = drug_usage_cols_series.sort_values('heavy_user', ascending=False)

# %%
drug_usage_cols_series.head(6)
# Out:
#           Usage Frequency  heavy_user
# 0              Never Used       18889
# 6              Daily User        4192
# 3       Used in Last Year        3046
# 2     Used in Last Decade        3005
# 5             Weekly User        2598
# 1  Used Over a Decade Ago        2194

# %%
""" Creates barplot to visualize drug usage frequency distribution."""

plot_drug_usage_distribution(drug_usage_cols_series)

# %%
drug_usage_cols_series.head(6)
# Out:
#           Usage Frequency  heavy_user
# 0              Never Used       18889
# 6              Daily User        4192
# 3       Used in Last Year        3046
# 2     Used in Last Decade        3005
# 5             Weekly User        2598
# 1  Used Over a Decade Ago        2194

# %%
convert_usage_frequency_to_labels(added_usage_heavy_user_df_copy)
# Out:
#         ID   Age Gender                                          Education  \
# 0        2  29.5      M                                   Doctorate degree
# 1        3  39.5      M                  Professional certificate/ diploma
# 2        4  21.0      F                                     Masters degree
# 3        5  39.5      F                                   Doctorate degree
# 4        6  70.0      F                            Left school at 18 years
# ...    ...   ...    ...                                                ...
# 1879  1884  21.0      F  Some college or university, no certificate or ...
# 1880  1885  21.0      M  Some college or university, no certificate or ...
# 1881  1886  29.5      F                                  University degree
# 1882  1887  21.0      F  Some college or university, no certificate or ...
# 1883  1888  21.0      M  Some college or university, no certificate or ...
#
# ...

# %%
added_usage_heavy_user_df_copy.head()
# Out:
#    ID   Age Gender                          Education Country Ethnicity  \
# 0   2  29.5      M                   Doctorate degree      UK     White
# 1   3  39.5      M  Professional certificate/ diploma      UK     White
# 2   4  21.0      F                     Masters degree      UK     White
# 3   5  39.5      F                   Doctorate degree      UK     White
# 4   6  70.0      F            Left school at 18 years  Canada     White
#
#    neuroticism_nscore  extraversion_escore  openness_oscore  \
# 0                0.41                 0.80             0.76
# 1                0.44                 0.62             0.39
# 2                0.49                 0.38             0.53
# 3                0.62                 0.25             0.46
# 4                0.41                 0.45             0.28
#
#    agreeableness_ascore  ...  LSD  methamphetamine  magic_mushrooms  Nicotine  \
# 0                  0.61  ...    2                3                0         4
# ...

# %%
""" Creates graphs for visualization of heavy users"""

combine_and_plot_heavy_users(drug_usage_cols_series)
# Out:
#           Usage Frequency  heavy_user
# 0              Never Used       18889
# 5              Heavy User        6790
# 1       Used in Last Year        3046
# 2     Used in Last Decade        3005
# 3  Used Over a Decade Ago        2194
# 4            Monthly User        1872

# %%
added_usage_heavy_user_df_copy.head()
# Out:
#    ID   Age Gender                          Education Country Ethnicity  \
# 0   2  29.5      M                   Doctorate degree      UK     White
# 1   3  39.5      M  Professional certificate/ diploma      UK     White
# 2   4  21.0      F                     Masters degree      UK     White
# 3   5  39.5      F                   Doctorate degree      UK     White
# 4   6  70.0      F            Left school at 18 years  Canada     White
#
#    neuroticism_nscore  extraversion_escore  openness_oscore  \
# 0                0.41                 0.80             0.76
# 1                0.44                 0.62             0.39
# 2                0.49                 0.38             0.53
# 3                0.62                 0.25             0.46
# 4                0.41                 0.45             0.28
#
#    agreeableness_ascore  ...  LSD  methamphetamine  magic_mushrooms  Nicotine  \
# 0                  0.61  ...    2                3                0         4
# ...

# %%
"""Cleans the column names of the main DataFrame by stripping whitespace, converting to lowercase, and replacing spaces with underscores."""

# renamed_added_usage_heavy_user_df_copy = added_usage_heavy_user_df_copy.copy()
cleaned_drug_df = clean_column_names(added_usage_heavy_user_df_copy)

# %%
cleaned_drug_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1884 entries, 0 to 1883
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1884 non-null   int64
#  1   age                       1884 non-null   float64
#  2   gender                    1884 non-null   object
#  3   education                 1884 non-null   object
#  4   country                   1884 non-null   object
#  5   ethnicity                 1884 non-null   object
#  6   neuroticism_nscore        1884 non-null   float64
#  7   extraversion_escore       1884 non-null   float64
#  8   openness_oscore           1884 non-null   float64
#  9   agreeableness_ascore      1884 non-null   float64
#  10  conscientiousness_cscore  1884 non-null   float64
#  11  impulsivity_impulsive     1884 non-null   float64
#  12  sensation_seeking_ss      1884 non-null   float64
# ...

# %%
cleaned_drug_df.head()
# Out:
#    id   age gender                          education country ethnicity  \
# 0   2  29.5      M                   Doctorate degree      UK     White
# 1   3  39.5      M  Professional certificate/ diploma      UK     White
# 2   4  21.0      F                     Masters degree      UK     White
# 3   5  39.5      F                   Doctorate degree      UK     White
# 4   6  70.0      F            Left school at 18 years  Canada     White
#
#    neuroticism_nscore  extraversion_escore  openness_oscore  \
# 0                0.41                 0.80             0.76
# 1                0.44                 0.62             0.39
# 2                0.49                 0.38             0.53
# 3                0.62                 0.25             0.46
# 4                0.41                 0.45             0.28
#
#    agreeableness_ascore  ...  lsd  methamphetamine  magic_mushrooms  nicotine  \
# 0                  0.61  ...    2                3                0         4
# ...

# %%
"""Saves the cleaned DataFrame to a CSV file."""

save_cleaned_dataset(cleaned_drug_df, FILEPATH_CLEANED)
